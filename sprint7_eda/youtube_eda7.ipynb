# %%
from sqlalchemy import create_engine, func
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
import pandas as pd
import config

engine = create_engine(f"postgresql+psycopg2://{config.user}:{config.password}@{config.host}:{config.port}/{config.dbname}")
Base = automap_base()
Base.prepare(engine, schema='market', reflect=True)

youtube = Base.classes.youtube

session = Session(engine)

youtube_result = session.query(youtube)

yt_df = pd.read_sql(youtube_result.statement, con=engine.connect())
# Out:
# C:\Users\jonna\AppData\Local\Temp\ipykernel_17132\1232936734.py:9: SADeprecationWarning: The AutomapBase.prepare.reflect parameter is deprecated and will be removed in a future release.  Reflection is enabled when AutomapBase.prepare.autoload_with is passed.
#   Base.prepare(engine, schema='market', reflect=True)

# %%
# Out:
#              id                                              title  \
# 0   XSv9L3X06no  #ThrowbackThursday KKCF Closing reflections - ...
# 1   MRK-udGUqHE                                    TKH 2022 Recap!
# 2   6ROEezBabdk  I wanted to learn more about what's out there ...
# 3   dmMYfGAHPsA  I am part of this prestigious fellowship becau...
# 4   dKELjCM5cnM  My life changed with an opportunity â€¦ - Edwa...
# ..          ...                                                ...
# 65  pWzVLrwgXlI  From Tech User to Tech Creator! Join The Knowl...
# 66  WtHVIJaeFjc  UNPACKING: Hiring Bias in Technology - Gender ...
# 67  il66kN0U8eg                                          Our Story
# 68  8l2MjE2uWY4  Bridge to Tech: Digital Communications Pre-Tra...
# 69  2IYh_aoqIGc  UNPACKING: Hiring Bias in Technology - Racial ...
#
#                                             url  viewcount        date  likes  \
# 0   https://www.youtube.com/watch?v=XSv9L3X06no         23  2023-01-12      1
# 1   https://www.youtube.com/watch?v=MRK-udGUqHE         79  2022-12-31      4
# 2   https://www.youtube.com/watch?v=6ROEezBabdk         22  2022-12-23      1
# 3   https://www.youtube.com/watch?v=dmMYfGAHPsA         28  2022-12-20      4
# 4   https://www.youtube.com/watch?v=dKELjCM5cnM         41  2022-12-13      8
# ..                                          ...        ...         ...    ...
# 65  https://www.youtube.com/watch?v=pWzVLrwgXlI        101  2022-05-31      1
# 66  https://www.youtube.com/watch?v=WtHVIJaeFjc         10  2022-04-20      1
# 67  https://www.youtube.com/watch?v=il66kN0U8eg         46  2021-09-11      2
# 68  https://www.youtube.com/watch?v=8l2MjE2uWY4        117  2019-03-26      2
# 69  https://www.youtube.com/watch?v=2IYh_aoqIGc         24  2022-03-22      0
#
#    duration  commentscount
# 0      0:51            0.0
# 1      1:43            1.0
# 2      1:43            0.0
# 3       1:0            0.0
# 4       2:2            0.0
# ..      ...            ...
# 65      1:3            0.0
# 66     58:6            0.0
# 67      1:0            0.0
# 68     7:39            0.0
# 69    54:45            0.0
#
# [70 rows x 8 columns]
