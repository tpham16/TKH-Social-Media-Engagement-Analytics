# %%
import pandas as pd

# Load JSON file into a DataFrame
json_file_path = r"C:\Users\jonna\Desktop\TKH\TKH-Social-Media-Engagement-Analytics\data\dataset_youtube-scraper-task_2023-04-12_01-17-09-624.json"
df = pd.read_json(json_file_path)
pd.set_option('display.max_columns', None)

df.head(5)
# Out:
#                                                title           id  \
# 0  #ThrowbackThursday KKCF Closing reflections - ...  XSv9L3X06no
# 1                                    TKH 2022 Recap!  MRK-udGUqHE
# 2  I wanted to learn more about what's out there ...  6ROEezBabdk
# 3  I am part of this prestigious fellowship becau...  dmMYfGAHPsA
# 4  My life changed with an opportunity … - Edward...  dKELjCM5cnM
#
#                                            url  \
# 0  https://www.youtube.com/watch?v=XSv9L3X06no
# 1  https://www.youtube.com/watch?v=MRK-udGUqHE
# 2  https://www.youtube.com/watch?v=6ROEezBabdk
# 3  https://www.youtube.com/watch?v=dmMYfGAHPsA
# 4  https://www.youtube.com/watch?v=dKELjCM5cnM
#
#                                         thumbnailUrl  viewCount       date  \
# 0  https://i.ytimg.com/vi/XSv9L3X06no/maxresdefau...         23 2023-01-12
# 1  https://i.ytimg.com/vi/MRK-udGUqHE/maxresdefau...         79 2022-12-31
# ...
