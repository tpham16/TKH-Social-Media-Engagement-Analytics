# %%
import pandas as pd

# Load JSON file into a DataFrame
json_file_path = "/Users/ezequielesparza/TKH-Social-Media-Engagement-Analytics/data/dataset_youtube-scraper-task_2023-04-12_01-17-09-624.json"
df = pd.read_json(json_file_path)
pd.set_option('display.max_columns', None)

df
# Out:
#                                                 title           id  \
# 0   #ThrowbackThursday KKCF Closing reflections - ...  XSv9L3X06no
# 1                                     TKH 2022 Recap!  MRK-udGUqHE
# 2   I wanted to learn more about what's out there ...  6ROEezBabdk
# 3   I am part of this prestigious fellowship becau...  dmMYfGAHPsA
# 4   My life changed with an opportunity … - Edward...  dKELjCM5cnM
# ..                                                ...          ...
# 65  From Tech User to Tech Creator! Join The Knowl...  pWzVLrwgXlI
# 66  UNPACKING: Hiring Bias in Technology - Gender ...  WtHVIJaeFjc
# 67                                          Our Story  il66kN0U8eg
# 68  Bridge to Tech: Digital Communications Pre-Tra...  8l2MjE2uWY4
# 69  UNPACKING: Hiring Bias in Technology - Racial ...  2IYh_aoqIGc
#
#                                             url  \
# 0   https://www.youtube.com/watch?v=XSv9L3X06no
# 1   https://www.youtube.com/watch?v=MRK-udGUqHE
# ...
