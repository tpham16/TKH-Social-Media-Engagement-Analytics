# %%
import pandas as pd

json_file_path = "/Users/ezequielesparza/TKH-Social-Media-Engagement-Analytics/data/dataset_instagram-scraper_2023-04-11_20-38-43-027.json"
df = pd.read_json(json_file_path)
pd.set_option('display.max_columns', None)

df
# Out:
#                id     type    shortCode  \
# 0    3.075855e+18  Sidecar  CqvoZzULx7e
# 1    3.070079e+18    Image  CqbHD33vMiW
# 2    3.078740e+18    Video  Cq54bj-vztp
# 3    3.073725e+18    Image  CqoEOzPPV9h
# 4    3.069354e+18    Image  CqYiRTGrGDa
# ..            ...      ...          ...
# 191  2.820809e+18    Image  CclhmzLlycJ
# 192  2.815645e+18    Image  CcTLclmLLG7
# 193  2.827317e+18    Image  Cc8pXs7FC3X
# 194  2.821493e+18    Image  Ccn9P0fFlXZ
# 195  2.822243e+18    Image  CcqnzymFf7G
#
#                                                caption  \
# 0    #Tech is increasingly becoming an #EssentialTo...
# 1    Informational #interviews are essential for #c...
# 2    Come on by this #Saturday, April 15th at 1pm, ...
# 3    It’s #TechTuesday! Today we'll be talking abou...
# 4    It's #WomenCrushWednesday and today we're chec...
# ..                                                 ...
# 191  We had a wonderful information session with @n...
# 192  In honor of #nationalvolunteermonth, we are re...
# 193  It's that time of the month to announce our #S...
# 194  For our Volunteer Spotlight this week, we are ...
# 195  Calling #highschool students in New York, Los ...
#
#                                               hashtags  \
# 0    [Tech, EssentialTool, jobs., TapIn, TechIndust...
# 1    [interviews, career, interviewing., ExpandOppr...
# 2    [Saturday,, OpenHouse!, BronxEvents, NYC, NewY...
# 3    [TechTuesday!, DayintheLife, WebDevelopment., ...
# 4    [WomenCrushWednesday, India., WomenSupportingW...
# ..                                                 ...
# 191  [ExpandOpportunity, Tech, TechProgram, Coding,...
# 192  [nationalvolunteermonth,, ExpandOpportunity, v...
# 193  [StaffoftheMonth,, ExpandOpportunity, StaffApp...
# 194  [ExpandOpportunity, volunteer, community, volu...
# 195  [highschool, ExpandOpportunity, Tech, TechProg...
#
#                      mentions                                       url  \
# 0                          []  https://www.instagram.com/p/CqvoZzULx7e/
# 1                          []  https://www.instagram.com/p/CqbHD33vMiW/
# 2                          []  https://www.instagram.com/p/Cq54bj-vztp/
# 3                          []  https://www.instagram.com/p/CqoEOzPPV9h/
# 4                          []  https://www.instagram.com/p/CqYiRTGrGDa/
# ..                        ...                                       ...
# 191  [newvillagegirlsacademy]  https://www.instagram.com/p/CclhmzLlycJ/
# 192         [ayoitscrowder).]  https://www.instagram.com/p/CcTLclmLLG7/
# 193                        []  https://www.instagram.com/p/Cc8pXs7FC3X/
# 194                        []  https://www.instagram.com/p/Ccn9P0fFlXZ/
# 195  [theknowledgehouse.org.]  https://www.instagram.com/p/CcqnzymFf7G/
#
#      commentsCount                                       firstComment  \
# 0              1.0                                                 👏🏼
# 1              0.0
# 2              0.0
# 3              1.0  Excited to give back and share with my communi...
# 4              1.0  Fantastic\nphoto, we  would certainly  like to...
# ..             ...                                                ...
# 191            2.0                   Wow 🤗 send pics @black.familye_😍
# 192            0.0
# 193            0.0
# 194            0.0
# 195            1.0                  Send pic here @Blacks_community‼️
#
#                                         latestComments  dimensionsHeight  \
# 0    [{'id': '17980439755908690', 'text': '👏🏼', 'ow...            1080.0
# 1                                                   []            1080.0
# 2                                                   []            1137.0
# 3    [{'id': '17987013259901690', 'text': 'Excited ...            1080.0
# 4    [{'id': '17996539900770096', 'text': 'Fantasti...            1080.0
# ..                                                 ...               ...
# 191  [{'id': '17958334312681006', 'text': 'Wow 🤗 se...             810.0
# 192                                                 []            1080.0
# 193                                                 []            1080.0
# 194                                                 []            1080.0
# 195  [{'id': '17945705197905011', 'text': 'Send pic...            1080.0
#
#      dimensionsWidth                                         displayUrl  \
# 0             1080.0  https://instagram.fntr5-1.fna.fbcdn.net/v/t51....
# 1             1080.0  https://scontent-hbe1-1.cdninstagram.com/v/t51...
# 2              640.0  https://instagram.fbdo9-1.fna.fbcdn.net/v/t51....
# 3             1080.0  https://scontent-lcy1-1.cdninstagram.com/v/t51...
# 4             1080.0  https://z-p42-instagram.fadb6-4.fna.fbcdn.net/...
# ..               ...                                                ...
# 191           1080.0  https://scontent-fra5-2.cdninstagram.com/v/t51...
# 192           1080.0  https://instagram.fopo6-1.fna.fbcdn.net/v/t51....
# 193           1080.0  https://scontent-mia3-1.cdninstagram.com/v/t51...
# 194           1080.0  https://instagram.fssa12-1.fna.fbcdn.net/v/t51...
# 195           1080.0  https://instagram.fnqn1-1.fna.fbcdn.net/v/t51....
#
#                                                 images  likesCount  \
# 0    [https://instagram.fntr5-1.fna.fbcdn.net/v/t51...        17.0
# 1                                                   []        17.0
# 2                                                   []         8.0
# 3                                                   []        17.0
# 4                                                   []        10.0
# ..                                                 ...         ...
# 191                                                 []        31.0
# 192                                                 []        17.0
# 193                                                 []        12.0
# 194                                                 []        16.0
# 195                                                 []        19.0
#
#                     timestamp  \
# 0   2023-04-07 18:01:40+00:00
# 1   2023-03-30 18:45:16+00:00
# 2   2023-04-11 17:35:00+00:00
# 3   2023-04-04 19:30:37+00:00
# 4   2023-03-29 18:45:18+00:00
# ..                        ...
# 191 2022-04-20 20:30:06+00:00
# 192 2022-04-13 17:30:09+00:00
# 193 2022-04-29 20:00:28+00:00
# 194 2022-04-21 19:10:07+00:00
# 195 2022-04-22 20:00:30+00:00
#
#                                             childPosts        ownerFullName  \
# 0    [{'id': '3075854752495254239', 'type': 'Image'...  The Knowledge House
# 1                                                   []  The Knowledge House
# 2                                                   []  The Knowledge House
# 3                                                   []  The Knowledge House
# 4                                                   []  The Knowledge House
# ..                                                 ...                  ...
# 191                                                 []  The Knowledge House
# 192                                                 []  The Knowledge House
# 193                                                 []  The Knowledge House
# 194                                                 []  The Knowledge House
# 195                                                 []  The Knowledge House
#
#          ownerUsername       ownerId  isSponsored  alt  \
# 0    theknowledgehouse  1.133084e+09          0.0  NaN
# 1    theknowledgehouse  1.133084e+09          0.0  NaN
# 2    theknowledgehouse  1.133084e+09          0.0  NaN
# 3    theknowledgehouse  1.133084e+09          0.0  NaN
# 4    theknowledgehouse  1.133084e+09          0.0  NaN
# ..                 ...           ...          ...  ...
# 191  theknowledgehouse  1.133084e+09          0.0  NaN
# 192  theknowledgehouse  1.133084e+09          0.0  NaN
# 193  theknowledgehouse  1.133084e+09          0.0  NaN
# 194  theknowledgehouse  1.133084e+09          0.0  NaN
# 195  theknowledgehouse  1.133084e+09          0.0  NaN
#
#                                               videoUrl  videoViewCount  \
# 0                                                  NaN             NaN
# 1                                                  NaN             NaN
# 2    https://instagram.fbdo9-1.fna.fbcdn.net/v/t66....            97.0
# 3                                                  NaN             NaN
# 4                                                  NaN             NaN
# ..                                                 ...             ...
# 191                                                NaN             NaN
# 192                                                NaN             NaN
# 193                                                NaN             NaN
# 194                                                NaN             NaN
# 195                                                NaN             NaN
#
#      videoPlayCount        locationName   locationId productType  \
# 0               NaN                 NaN          NaN         NaN
# 1               NaN                 NaN          NaN         NaN
# 2             242.0  New York, New York  212988663.0       clips
# 3               NaN                 NaN          NaN         NaN
# 4               NaN                 NaN          NaN         NaN
# ..              ...                 ...          ...         ...
# 191             NaN                 NaN          NaN         NaN
# 192             NaN                 NaN          NaN         NaN
# 193             NaN                 NaN          NaN         NaN
# 194             NaN                 NaN          NaN         NaN
# 195             NaN                 NaN          NaN         NaN
#
#      videoDuration                                        taggedUsers title  \
# 0              NaN                                                NaN   NaN
# 1              NaN                                                NaN   NaN
# 2            5.202                                                NaN   NaN
# 3              NaN  [{'full_name': 'Lidia • Software Engineer •Afr...   NaN
# 4              NaN                                                NaN   NaN
# ..             ...                                                ...   ...
# 191            NaN                                                NaN   NaN
# 192            NaN                                                NaN   NaN
# 193            NaN  [{'full_name': 'Alondra Diaz', 'id': '45629878...   NaN
# 194            NaN  [{'full_name': 'Capital One', 'id': '578045120...   NaN
# 195            NaN                                                NaN   NaN
#
#     description
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 191         NaN
# 192         NaN
# 193         NaN
# 194         NaN
# 195         NaN
#
# [196 rows x 32 columns]

# %%
null_counts = df.isnull().sum()
print(null_counts)
# Out:
# id                    1
# type                  1
# shortCode             1
# caption               1
# hashtags              1
# mentions              1
# url                   1
# commentsCount         1
# firstComment          1
# latestComments        1
# dimensionsHeight      1
# dimensionsWidth       1
# displayUrl            1
# images                1
# likesCount            1
# timestamp             1
# childPosts            1
# ownerFullName         1
# ownerUsername         1
# ownerId               1
# isSponsored           1
# alt                 196
# videoUrl            139
# videoViewCount      139
# videoPlayCount      160
# locationName        133
# locationId          133
# productType         139
# videoDuration       139
# taggedUsers         154
# title               195
# description         195
# dtype: int64

# %%
is_sponse = df[df['isSponsored'] == 1]
is_sponse
# Out:
# Empty DataFrame
# Columns: [id, type, shortCode, caption, hashtags, mentions, url, commentsCount, firstComment, latestComments, dimensionsHeight, dimensionsWidth, displayUrl, images, likesCount, timestamp, childPosts, ownerFullName, ownerUsername, ownerId, isSponsored, alt, videoUrl, videoViewCount, videoPlayCount, locationName, locationId, productType, videoDuration, taggedUsers, title, description]
# Index: []

# %%
import matplotlib.pyplot as plt

null_counts = df.isnull().sum()
null_counts.plot(kind='bar')
plt.show()

# %%
# drop columns with over 190 null values
df = df.drop(['id', 'shortCode', 'url', 'dimensionsHeight', 'dimensionsWidth', 'displayUrl', 'images', 'childPosts', 'ownerFullName', 'ownerUsername', 'ownerId', 'isSponsored', 'alt', 'videoUrl', 'locationName', 'locationId', 'productType','taggedUsers' ,'title', 'description'], axis=1)

# %%
hashtag_likes = df.explode('hashtags').groupby('hashtags')['likesCount'].sum().sort_values(ascending=False)
hashtag_likes
# Out:
# hashtags
# ExpandOpportunity    3472.0
# KnowledgePays        1091.0
# LosAngeles            968.0
# Tech                  925.0
# Atlanta               838.0
#                       ...
# latinx                  5.0
# healthcheck             5.0
# HIVTesting              5.0
# nyc                     5.0
# healthfair              5.0
# Name: likesCount, Length: 648, dtype: float64

# %%
df_exploded = df.explode('hashtags')
df_exploded
df_exploded.to_csv('IG_cleaned_data.csv', index=False)
